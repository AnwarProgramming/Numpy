# %% [markdown]
# <a href="https://colab.research.google.com/github/AnwarProgramming/Numpy/blob/main/phase_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Numpy array and basics
# Learn about numpy

# %%
import numpy as np
